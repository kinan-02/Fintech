# %%
import pandas as pd

# %%
df = pd.read_parquet('/content/GLD.parquet')
df
# Out:
#                        timestamp      open      high       low     close  \
# 0      2023-01-03 09:01:00+00:00  170.8500  170.8500  170.8500  170.8500
# 1      2023-01-03 09:06:00+00:00  170.7400  170.7400  170.7400  170.7400
# 2      2023-01-03 09:08:00+00:00  170.8000  170.8000  170.8000  170.8000
# 3      2023-01-03 09:09:00+00:00  170.8800  170.8800  170.8800  170.8800
# 4      2023-01-03 09:16:00+00:00  171.0000  171.0000  171.0000  171.0000
# ...                          ...       ...       ...       ...       ...
# 186854 2024-06-28 21:34:00+00:00  215.2300  215.2300  215.2300  215.2300
# 186855 2024-06-28 21:47:00+00:00  215.3500  215.3500  215.3500  215.3500
# 186856 2024-06-28 21:58:00+00:00  215.1189  215.1189  215.1189  215.1189
# 186857 2024-06-28 23:08:00+00:00  215.0100  215.0100  215.0100  215.0100
# 186858 2024-06-28 23:47:00+00:00  215.0300  215.0300  215.0300  215.0300
#
#         volume  trade_count        vwap
# 0        120.0          2.0  170.843333
# ...

# %%
df1 = pd.read_parquet('/content/CL.parquet')
df1
# Out:
#                        timestamp   open   high     low   close    volume  \
# 0      2023-01-03 13:03:00+00:00  79.01  79.01  79.010  79.010     152.0
# 1      2023-01-03 13:44:00+00:00  78.87  78.87  78.860  78.860     353.0
# 2      2023-01-03 14:30:00+00:00  78.79  78.81  78.640  78.775   55585.0
# 3      2023-01-03 14:31:00+00:00  78.67  78.71  78.595  78.710    2425.0
# 4      2023-01-03 14:32:00+00:00  78.70  78.76  78.650  78.670    2742.0
# ...                          ...    ...    ...     ...     ...       ...
# 148274 2024-06-28 20:03:00+00:00  97.04  97.04  97.040  97.040   30796.0
# 148275 2024-06-28 20:10:00+00:00  97.04  97.04  97.040  97.040  200111.0
# 148276 2024-06-28 20:38:00+00:00  97.23  97.23  97.230  97.230     200.0
# 148277 2024-06-28 20:54:00+00:00  97.23  97.23  97.230  97.230     762.0
# 148278 2024-06-28 23:22:00+00:00  96.60  96.60  96.600  96.600     150.0
#
#         trade_count       vwap
# 0               4.0  79.014342
# ...

# %%
df3 = pd.read_parquet('/content/MSTR.parquet')
df3
# Out:
#                        timestamp     open     high        low      close  \
# 0      2023-01-03 12:01:00+00:00   143.00   143.00   143.0000   143.0000
# 1      2023-01-03 12:55:00+00:00   143.13   143.13   143.1300   143.1300
# 2      2023-01-03 13:27:00+00:00   143.32   143.32   143.3200   143.3200
# 3      2023-01-03 14:29:00+00:00   144.97   144.97   144.9700   144.9700
# 4      2023-01-03 14:30:00+00:00   144.59   146.39   144.0001   144.0001
# ...                          ...      ...      ...        ...        ...
# 146729 2024-06-28 22:07:00+00:00  1369.99  1369.99  1369.9900  1369.9900
# 146730 2024-06-28 22:55:00+00:00  1370.43  1370.43  1370.4300  1370.4300
# 146731 2024-06-28 22:58:00+00:00  1370.43  1370.43  1370.4300  1370.4300
# 146732 2024-06-28 23:12:00+00:00  1370.00  1370.00  1370.0000  1370.0000
# 146733 2024-06-28 23:25:00+00:00  1372.52  1372.52  1372.5200  1372.5200
#
# 640897 2024-06-30 23:59:00+00:00  62669.7615  62669.7615  62669.7615
#
#              close    volume  trade_count          vwap
# 0       16526.7100  0.501588         32.0  16526.222459
# ...

# %%
 # Converting to timezone-naive
df2 = df5
df2['timestamp'] = pd.to_datetime(df2['timestamp']).dt.tz_localize(None)

# Set 'timestamp' as the index
df2.set_index('timestamp', inplace=True)

# Create a complete range of timestamps from the first timestamp to the last
complete_index = pd.date_range(start='2023-01-03', end='2024-07-01', freq='T')

# Reindex the dataframe to this complete range
df2_reindexed = pd.DataFrame(index=complete_index)

# Find missing timestamps
missing_timestamps = complete_index.difference(df2.index)

# Create a DataFrame for missing timestamps with NaN values

df_missing = pd.DataFrame(index=missing_timestamps, columns=df2.columns)
df_missing['trade_count'] = 0
df_missing['volume'] = 0

# Concatenate the original DataFrame with the missing timestamps DataFrame
df2_combined = pd.concat([df2, df_missing]).sort_index()

# Use LOCF to fill in missing data
df2_filled = df2_combined.ffill()
# Out:
# <ipython-input-86-b38590e663a7>:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df2_combined = pd.concat([df2, df_missing]).sort_index()

# %%
df2
# Out:
#                       open    high     low   close   volume  trade_count  \
# timestamp
# 2023-01-03 09:00:00  28.00  28.020  28.000  28.020    219.0          6.0
# 2023-01-03 12:00:00  28.00  28.050  28.000  28.050   1957.0         10.0
# 2023-01-03 12:21:00  27.98  27.990  27.980  27.990   2717.0          6.0
# 2023-01-03 12:27:00  27.98  28.000  27.980  28.000    300.0          5.0
# 2023-01-03 12:59:00  27.99  28.000  27.990  28.000   1000.0          3.0
# ...                    ...     ...     ...     ...      ...          ...
# 2024-06-28 19:57:00  29.14  29.145  29.140  29.140  32562.0         32.0
# 2024-06-28 19:58:00  29.14  29.140  29.135  29.135  37011.0         47.0
# 2024-06-28 19:59:00  29.14  29.140  29.130  29.140  77404.0        104.0
# 2024-06-28 20:00:00  29.13  29.130  29.130  29.130  71422.0         21.0
# 2024-06-28 20:39:00  29.15  29.150  29.150  29.150    218.0          1.0
#
#                           vwap
# timestamp
# 2023-01-03 09:00:00  27.992192
# ...

# %%
df2_filled
# Out:
#                       open   high    low  close  volume  trade_count   vwap
# 2023-01-03 00:00:00    NaN    NaN    NaN    NaN     0.0          0.0    NaN
# 2023-01-03 00:01:00    NaN    NaN    NaN    NaN     0.0          0.0    NaN
# 2023-01-03 00:02:00    NaN    NaN    NaN    NaN     0.0          0.0    NaN
# 2023-01-03 00:03:00    NaN    NaN    NaN    NaN     0.0          0.0    NaN
# 2023-01-03 00:04:00    NaN    NaN    NaN    NaN     0.0          0.0    NaN
# ...                    ...    ...    ...    ...     ...          ...    ...
# 2024-06-30 23:56:00  29.15  29.15  29.15  29.15     0.0          0.0  29.15
# 2024-06-30 23:57:00  29.15  29.15  29.15  29.15     0.0          0.0  29.15
# 2024-06-30 23:58:00  29.15  29.15  29.15  29.15     0.0          0.0  29.15
# 2024-06-30 23:59:00  29.15  29.15  29.15  29.15     0.0          0.0  29.15
# 2024-07-01 00:00:00  29.15  29.15  29.15  29.15     0.0          0.0  29.15
#
# [784801 rows x 7 columns]

# %%
df2_filled.to_parquet('UUP2023_New.parquet')
